# %%
def reverse_string(s:str):
    if len(s)==1:
        return s
    else:
        return s[::-1]
    
print(reverse_string(s='geek'))
print(reverse_string(s='abhinandan'))
    
# Time complexity: O(n)
# Space complexity: O(n)
# Out:
# keeg
# nadnanihba
