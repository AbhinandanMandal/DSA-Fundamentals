# %%
# method 1
def reverse_string(s:str):
    if len(s)==1:
        return s
    else:
        return s[::-1]
    
print(reverse_string(s='geek'))
# Out:
# keeg

# %%
# method 2
s='abhinandan'
rev=''
for i in s:
    rev=i+rev
print(rev)
# Out:
# nadnanihba
